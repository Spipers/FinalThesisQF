# %% [markdown]
# # Initialising

# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt

from numpy import mean
from numpy import std
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
# Out:
# Python(42965) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.

# %% [markdown]
# # sample splitting code

# %%
def initialise(data):
  data.index = data["date"]
  data.index = pd.to_datetime(data.index)
  data.drop(columns=["date"], inplace=True)
  return data

# %% [markdown]
# #  Download data

# %% [markdown]
# Data standardised with dummies

# %%
data = initialise(pd.read_csv('/Users/sbjpipers/Desktop/FinalThesisQF/FinalThesisQF/Data/standardized_features.csv'))
data.head()
# Out:
#            m_category maturity_group Ticker cp_flag   10Y_RIR   1Y_bond  \
# date
# 2019-01-02   -0.5<m≤0            τ≤5   AMZN       C  1.570328  1.377608
# 2019-01-03   -0.5<m≤0            τ≤5   AMZN       C  1.584014  1.361279
# 2019-01-04   -0.5<m≤0            τ≤5   AMZN       C  1.666128  1.425530
# 2019-01-07   -0.5<m≤0            τ≤5   AMZN       C  1.679813  1.412402
# 2019-01-08   -0.5<m≤0            τ≤5   AMZN       C  1.638756  1.396926
#
#              2Y_bond  5_day_rolling_return_stock  CLOSE_vix   FF_rate  ...  \
# date                                                                   ...
# 2019-01-02  1.476082                    3.270356   0.072392  1.129054  ...
# 2019-01-03  1.448286                    1.653302  -0.066357  1.129054  ...
# 2019-01-04  1.533572                    2.255845  -0.117068  1.129054  ...
# 2019-01-07  1.526874                    2.279905  -0.285399  1.129054  ...
# 2019-01-08  1.503097                   -0.395013  -0.334701  1.129054  ...
#
#             std_dolvol  std_turn    stdacc     stdcf      tang        tb  \
# date
# 2019-01-02   -0.151172  0.585236  2.904893  2.570103 -1.427066 -0.909436
# 2019-01-03   -0.287074  0.626275  2.814569  2.492551 -1.427066 -0.909436
# 2019-01-04   -0.558880  0.708355  2.633922  2.337447 -1.427066 -0.909436
# 2019-01-07   -0.694782  0.749394  2.543598  2.259896 -1.427066 -0.909436
# 2019-01-08   -0.966588  0.831474  2.362951  2.104792 -1.427066 -0.909436
#
#                 turn  vol_stock  volume_option  zerotrade
# date
# 2019-01-02  1.792539   1.909975      -0.157176  -1.472106
# 2019-01-03  1.843875   2.551264      -0.617537  -1.472933
# 2019-01-04  1.946549   2.390603      -0.074442  -1.474589
# 2019-01-07  1.997886   1.123586       0.553042  -1.475416
# 2019-01-08  2.100559   0.855694      -0.746967  -1.477071
#
# [5 rows x 119 columns]

# %% [markdown]
# Data standardised without dummies

# %%
# data_final = initialise(pd.read_csv('/content/drive/MyDrive/Msc Thesis/code/data/Low resolution/data_final_low.csv'))
# data_final.head()

# %% [markdown]
# Data mapped

# %%
# data_mapped = initialise(pd.read_csv('/content/drive/MyDrive/Msc Thesis/code/data/Low resolution/data_mapped.csv'))
# data_mapped.head()

# %% [markdown]
# Data standardised

# %%
# data = initialise(pd.read_csv('/content/drive/MyDrive/Msc Thesis/code/data/Low resolution/data_standardized.csv'))
# data.head()

# %% [markdown]
# Data standardised per period without SIC

# %%
# data = initialise(pd.read_csv('/content/drive/MyDrive/Msc Thesis/code/data/Low resolution/data_standardized_pp_nosic.csv'))
# data.head()

# %% [markdown]
# Standardised data with selected stocks

# %%
# data = initialise(pd.read_csv('/content/drive/MyDrive/Msc Thesis/code/data/Low resolution/data_standardized_selection10.csv'))
# data.head()

# %%
# data = initialise(pd.read_csv('/content/drive/MyDrive/Msc Thesis/code/data/Low resolution/data_mapped_selection10.csv'))
# data.head()

# %%
#Add a filter to make sure we first do only for a small bit
final_grouped_df = data.copy()
filter_version = final_grouped_df[(final_grouped_df['m_category'] == '-0.5<m≤0') & (final_grouped_df['maturity_group'] == 'τ≤5') & (final_grouped_df['Ticker'] == 'AMZN')]

# %%
filter_version
# Out:
#            m_category maturity_group Ticker cp_flag   10Y_RIR   1Y_bond  \
# date
# 2019-01-02   -0.5<m≤0            τ≤5   AMZN       C  1.570328  1.377608
# 2019-01-03   -0.5<m≤0            τ≤5   AMZN       C  1.584014  1.361279
# 2019-01-04   -0.5<m≤0            τ≤5   AMZN       C  1.666128  1.425530
# 2019-01-07   -0.5<m≤0            τ≤5   AMZN       C  1.679813  1.412402
# 2019-01-08   -0.5<m≤0            τ≤5   AMZN       C  1.638756  1.396926
# ...               ...            ...    ...     ...       ...       ...
# 2020-12-24   -0.5<m≤0            τ≤5   AMZN       P -0.769920 -1.210453
# 2020-12-28   -0.5<m≤0            τ≤5   AMZN       P -0.797291 -1.213975
# 2020-12-29   -0.5<m≤0            τ≤5   AMZN       P -0.783606 -1.211307
# 2020-12-30   -0.5<m≤0            τ≤5   AMZN       P -0.783606 -1.202128
# 2020-12-31   -0.5<m≤0            τ≤5   AMZN       P -0.797291 -1.212481
#
#              2Y_bond  5_day_rolling_return_stock  CLOSE_vix   FF_rate  ...  \
# date                                                                   ...
# 2019-01-02  1.476082                    3.270356   0.072392  1.129054  ...
# 2019-01-03  1.448286                    1.653302  -0.066357  1.129054  ...
# 2019-01-04  1.533572                    2.255845  -0.117068  1.129054  ...
# 2019-01-07  1.526874                    2.279905  -0.285399  1.129054  ...
# 2019-01-08  1.503097                   -0.395013  -0.334701  1.129054  ...
# ...              ...                         ...        ...       ...  ...
# 2020-12-24 -1.194798                    0.442283  -0.358647 -1.156186  ...
# 2020-12-28 -1.203951                    0.099924  -0.132563 -1.156186  ...
# 2020-12-29 -1.201161                   -0.683865  -0.329066 -1.156186  ...
# 2020-12-30 -1.196584                    0.652830  -0.022690 -1.156186  ...
# 2020-12-31 -1.207747                    0.325895  -0.041706 -1.156186  ...
#
#             std_dolvol  std_turn    stdacc     stdcf      tang        tb  \
# date
# 2019-01-02   -0.151172  0.585236  2.904893  2.570103 -1.427066 -0.909436
# 2019-01-03   -0.287074  0.626275  2.814569  2.492551 -1.427066 -0.909436
# 2019-01-04   -0.558880  0.708355  2.633922  2.337447 -1.427066 -0.909436
# 2019-01-07   -0.694782  0.749394  2.543598  2.259896 -1.427066 -0.909436
# 2019-01-08   -0.966588  0.831474  2.362951  2.104792 -1.427066 -0.909436
# ...                ...       ...       ...       ...       ...       ...
# 2020-12-24   -0.120683 -0.213325 -2.013912 -2.242562  1.440067  1.792197
# 2020-12-28    0.046449 -0.175860 -2.013912 -2.242562  1.440067  1.792197
# 2020-12-29    0.130014 -0.157127 -2.013912 -2.242562  1.440067  1.792197
# 2020-12-30    0.338928 -0.110295 -2.013912 -2.242562  1.440067  1.792197
# 2020-12-31    0.422494 -0.091562 -2.013912 -2.242562  1.440067  1.792197
#
#                 turn  vol_stock  volume_option  zerotrade
# date
# 2019-01-02  1.792539   1.909975      -0.157176  -1.472106
# 2019-01-03  1.843875   2.551264      -0.617537  -1.472933
# 2019-01-04  1.946549   2.390603      -0.074442  -1.474589
# 2019-01-07  1.997886   1.123586       0.553042  -1.475416
# 2019-01-08  2.100559   0.855694      -0.746967  -1.477071
# ...              ...        ...            ...        ...
# 2020-12-24  0.268081   0.841305       0.226442  -0.345995
# 2020-12-28  0.278463  -1.080821       2.333026  -0.192956
# 2020-12-29  0.283654  -1.579097      -0.104861  -0.116437
# 2020-12-30  0.296632   0.251313       4.023337   0.074862
# 2020-12-31  0.301823  -0.775703      -0.309809   0.151381
#
# [1010 rows x 119 columns]

# %% [markdown]
# # OLS ALL

# %%
# Complete number of observations is 680867
# We take the initial train, validate and oos sample to be 8, 5 and 13 years respectively (Ratios similar to Gu Kelly Xiu)
# On average one month contains 2000 options, therefore we loop over 12 * 2000 options, which is similar to looping over a year

# # Loop sizes
# trainsize = 2019
# validatesize = 2020
# oossize = 2021

# Loop sizes
trainsize = 1
validatesize = 1
oossize = 1

# Initialise predictionstring
IV = 'level'
oos_pred_level = pd.DataFrame()
oos_pred_slope = pd.DataFrame()
oos_pred_curve = pd.DataFrame()

for window in range(2012, 2021+1):
  print('Iteration: ', window)
  best = float("inf")

  # Sample splitting LEVEL
  IV = 'level'
  train, validate, oos, total_train, total_oos = samplesplitting(data, trainsize, validatesize, oossize, window)
  train_x, train_y              = split_xy(train,IV)
  validate_x, validate_y        = split_xy(validate,IV)
  oos_x, oos_y                  = split_xy(oos,IV)
  total_train_x, total_train_y  = split_xy(total_train,IV)

  # Fit model and produce forecasts
  model_final = LinearRegression()
  model_final.fit(total_train_x, total_train_y)

  # Compute predictions
  y_hat = pd.DataFrame(model_final.predict(oos_x))
  print('Yearly level:',r2_score(oos_y, y_hat))
  oos_pred_level = pd.concat([oos_pred_level, y_hat], ignore_index=True)
  print('Total level:',r2_score(total_oos[IV], oos_pred_level))

  # Sample splitting SLOPE
  IV = 'slope'
  train, validate, oos, total_train, total_oos = samplesplitting(data, trainsize, validatesize, oossize, window)
  train_x, train_y              = split_xy(train,IV)
  validate_x, validate_y        = split_xy(validate,IV)
  oos_x, oos_y                  = split_xy(oos,IV)
  total_train_x, total_train_y  = split_xy(total_train,IV)

  # Fit model and produce forecasts
  model_final = LinearRegression()
  model_final.fit(total_train_x, total_train_y)

  # Compute predictions
  y_hat = pd.DataFrame(model_final.predict(oos_x))
  print('Yearly slope:',r2_score(oos_y, y_hat))
  oos_pred_slope = pd.concat([oos_pred_slope, y_hat], ignore_index=True)
  print('Total slope:',r2_score(total_oos[IV], oos_pred_slope))

  # Sample splitting CURVE
  IV = 'curve'
  train, validate, oos, total_train, total_oos = samplesplitting(data, trainsize, validatesize, oossize, window)
  train_x, train_y              = split_xy(train,IV)
  validate_x, validate_y        = split_xy(validate,IV)
  oos_x, oos_y                  = split_xy(oos,IV)
  total_train_x, total_train_y  = split_xy(total_train,IV)

  # Fit model and produce forecasts
  model_final = LinearRegression()
  model_final.fit(total_train_x, total_train_y)

  # Compute predictions
  y_hat = pd.DataFrame(model_final.predict(oos_x))
  print('Yearly curve:',r2_score(oos_y, y_hat))
  oos_pred_curve = pd.concat([oos_pred_curve, y_hat], ignore_index=True)
  print('Total curve:',r2_score(total_oos[IV], oos_pred_curve))

oos_pred_level.to_csv('/content/drive/MyDrive/Msc Thesis/code/Results/OLS/level_predictions_OLSAll_st_yearly.csv', index=True)
oos_pred_slope.to_csv('/content/drive/MyDrive/Msc Thesis/code/Results/OLS/slope_predictions_OLSAll_st_yearly.csv', index=True)
oos_pred_curve.to_csv('/content/drive/MyDrive/Msc Thesis/code/Results/OLS/curve_predictions_OLSAll_st_yearly.csv', index=True)

# oos_pred_level.to_csv('/content/drive/MyDrive/Msc Thesis/code/Results/OLS/level_predictions_OLSAll_mp_yearly.csv', index=True)
# oos_pred_slope.to_csv('/content/drive/MyDrive/Msc Thesis/code/Results/OLS/slope_predictions_OLSAll_mp_yearly.csv', index=True)
# oos_pred_curve.to_csv('/content/drive/MyDrive/Msc Thesis/code/Results/OLS/curve_predictions_OLSAll_mp_yearly.csv', index=True)
# Out:
# Iteration:  2012
# train=210839, validate=158189, oos=33864
# Yearly level: 0.3654930241497434
# Total level: 0.3654930241497434
# train=210839, validate=158189, oos=33864
# Yearly slope: -0.015442941858514025
# Total slope: -0.015442941858514025
# train=210839, validate=158189, oos=33864
# Yearly curve: -0.03655715454808095
# Total curve: -0.03655715454808095
# Iteration:  2013
# train=241135, validate=161757, oos=34182
# Yearly level: 0.22168480981890304
# Total level: 0.30148953183612115
# train=241135, validate=161757, oos=34182
# Yearly slope: 0.01550993793076072
# Total slope: 0.003635972904047602
# train=241135, validate=161757, oos=34182
# Yearly curve: 0.00041403457891586726
# Total curve: -0.01625490494017101
# Iteration:  2014
# train=272284, validate=164790, oos=34113
# Yearly level: 0.30233898151997296
# Total level: 0.30277176242134585
# train=272284, validate=164790, oos=34113
# Yearly slope: -0.034601231816748346
# Total slope: -0.004455686401681369
# train=272284, validate=164790, oos=34113
# Yearly curve: -0.06859461825048307
# Total curve: -0.029246573087752248
# Iteration:  2015
# train=303150, validate=168037, oos=33074
# Yearly level: 0.4177155362792683
# Total level: 0.33318385384630056
# train=303150, validate=168037, oos=33074
# Yearly slope: -0.04321302927775972
# Total slope: -0.011475820368540779
# train=303150, validate=168037, oos=33074
# Yearly curve: -0.06349159849950192
# Total curve: -0.0354671044110042
# Iteration:  2016
# train=335237, validate=169024, oos=31906
# Yearly level: 0.48335603678811645
# Total level: 0.36679771592658805
# train=335237, validate=169024, oos=31906
# Yearly slope: -0.029482936687967864
# Total slope: -0.013937132356903081
# train=335237, validate=169024, oos=31906
# Yearly curve: -0.13800782904963538
# Total curve: -0.048640371271150284
# Iteration:  2017
# train=369028, validate=167139, oos=30972
# Yearly level: 0.268294488390294
# Total level: 0.35736643802243206
# train=369028, validate=167139, oos=30972
# Yearly slope: 0.02024333876282114
# Total slope: -0.008681157771971204
# train=369028, validate=167139, oos=30972
# Yearly curve: -0.033168583032366694
# Total curve: -0.04646072761644593
# Iteration:  2018
# train=402892, validate=164247, oos=30002
# Yearly level: 0.4127217301495857
# Total level: 0.3647877043181832
# train=402892, validate=164247, oos=30002
# Yearly slope: 0.004735232781387433
# Total slope: -0.006578217574402689
# train=402892, validate=164247, oos=30002
# Yearly curve: -0.02862193884547648
# Total curve: -0.0433769242995643
# Iteration:  2019
# train=437074, validate=160067, oos=28538
# Yearly level: 0.4749934085454285
# Total level: 0.3773276397498925
# train=437074, validate=160067, oos=28538
# Yearly slope: -0.001943061449659833
# Total slope: -0.005790044886993639
# train=437074, validate=160067, oos=28538
# Yearly curve: -0.03016160363534448
# Total curve: -0.04139921913242772
# Iteration:  2020
# train=471187, validate=154492, oos=27289
# Yearly level: 0.231487081131575
# Total level: 0.386347967244822
# train=471187, validate=154492, oos=27289
# Yearly slope: -0.08360054713094978
# Total slope: -0.010083100806917322
# train=471187, validate=154492, oos=27289
# Yearly curve: -0.06227838771910088
# Total curve: -0.041060741858010896
# Iteration:  2021
# train=504261, validate=148707, oos=27899
# Yearly level: 0.5172746209150634
# Total level: 0.4039412699401578
# train=504261, validate=148707, oos=27899
# Yearly slope: -0.08438426162840607
# Total slope: -0.012733026036299888
# train=504261, validate=148707, oos=27899
# Yearly curve: -0.07083607440430106
# Total curve: -0.041557858687518046

# %% [markdown]
# # Selected Features

# %% [markdown]
# ### Download data with selectected features

# %%
data_level = initialise(pd.read_csv('/content/drive/MyDrive/Msc Thesis/code/data/Low resolution/data_level_standardized_selection10.csv'))
data_slope = initialise(pd.read_csv('/content/drive/MyDrive/Msc Thesis/code/data/Low resolution/data_slope_standardized_selection10.csv'))
data_curve = initialise(pd.read_csv('/content/drive/MyDrive/Msc Thesis/code/data/Low resolution/data_curve_standardized_selection10.csv'))

# %%
data_level = initialise(pd.read_csv('/content/drive/MyDrive/Msc Thesis/code/data/Low resolution/data_level_mapped_selection10.csv'))
data_slope = initialise(pd.read_csv('/content/drive/MyDrive/Msc Thesis/code/data/Low resolution/data_slope_mapped_selection10.csv'))
data_curve = initialise(pd.read_csv('/content/drive/MyDrive/Msc Thesis/code/data/Low resolution/data_curve_mapped_selection10.csv'))

# %% [markdown]
# ### OLS data

# %%
data_curve.head()
# Out:
#              secid       -80       -50       -20     level     slope  \
# date
# 1996-01-31  100862  0.307688  0.315627  0.358095  0.315627  0.042468
# 1996-01-31  100871  0.705411  0.615432  0.651160  0.615432  0.035728
# 1996-01-31  100892  0.270090  0.216768  0.216508  0.216768 -0.000260
# 1996-01-31  100896  0.430796  0.436291  0.429517  0.436291 -0.006774
# 1996-01-31  100903  0.262405  0.252683  0.373839  0.252683  0.121156
#
#                curve  permno    betasq    dolvol  ...   cinvest    roavol  \
# date                                              ...
# 1996-01-31  0.017264   54594 -0.886445 -0.777471  ...  0.071798 -0.953113
# 1996-01-31  0.062854   50906  0.193703  0.751197  ...  0.080067 -0.900059
# 1996-01-31  0.026531   57904 -0.902575  0.329181  ...  0.066337 -0.998951
# 1996-01-31 -0.006135   77520 -0.101800  0.355979  ...  0.060739 -0.859083
# 1996-01-31  0.065439   80303 -0.682642  0.211679  ...  0.077826 -0.875346
#
#                 roeq      rsup    ms  baspread    maxret    retvol  \
# date
# 1996-01-31  0.281230 -0.105877  0.00 -0.689049 -0.662673 -0.619551
# 1996-01-31  0.325452 -0.155422  0.75 -0.112575 -0.390130 -0.223204
# 1996-01-31  0.345889  0.027781  0.25 -0.786859 -0.947305 -0.877289
# 1996-01-31  0.397384  0.633026 -0.25 -0.747736 -0.649524 -0.703492
# 1996-01-31  0.584032  0.043750 -0.50 -0.807682 -0.825541 -0.737079
#
#             std_dolvol  std_turn
# date
# 1996-01-31    0.327234 -0.936622
# 1996-01-31   -0.342296 -0.748948
# 1996-01-31   -0.536138 -0.955821
# 1996-01-31   -0.331142 -0.818216
# 1996-01-31   -0.400503 -0.866238
#
# [5 rows x 48 columns]

# %%
data_curve.head()
# Out:
#              secid       -80       -50       -20     level     slope  \
# date
# 1996-01-31  100862  0.307688  0.315627  0.358095  0.315627  0.042468
# 1996-01-31  100871  0.705411  0.615432  0.651160  0.615432  0.035728
# 1996-01-31  100892  0.270090  0.216768  0.216508  0.216768 -0.000260
# 1996-01-31  100896  0.430796  0.436291  0.429517  0.436291 -0.006774
# 1996-01-31  100903  0.262405  0.252683  0.373839  0.252683  0.121156
#
#                curve  permno    betasq    dolvol  ...   cinvest    roavol  \
# date                                              ...
# 1996-01-31  0.017264   54594 -0.628458 -2.342547  ...  0.090355 -0.491351
# 1996-01-31  0.062854   50906  2.509349  1.178146  ...  0.161215 -0.260014
# 1996-01-31  0.026531   57904 -0.675317  0.206196  ...  0.043550 -0.691224
# 1996-01-31 -0.006135   77520  1.650918  0.267915  ... -0.004423 -0.081339
# 1996-01-31  0.065439   80303 -0.036415 -0.064423  ...  0.142014 -0.152253
#
#                 roeq      rsup        ms  baspread    maxret    retvol  \
# date
# 1996-01-31 -0.291363  0.017690 -0.324628 -0.424243  0.383028 -0.139901
# 1996-01-31 -0.020269 -0.315352  1.735954  1.474995  1.612154  1.173917
# 1996-01-31  0.105018  0.916132  0.362233 -0.746485 -0.900621 -0.994256
# 1996-01-31  0.420696  4.984565 -1.011489 -0.617592  0.442328 -0.418152
# 1996-01-31  1.564896  1.023473 -1.698350 -0.815089 -0.351483 -0.529485
#
#             std_dolvol  std_turn
# date
# 1996-01-31    2.271301 -0.457693
# 1996-01-31    0.136424  0.297064
# 1996-01-31   -0.481665 -0.534902
# 1996-01-31    0.171988  0.018494
# 1996-01-31   -0.049179 -0.174634
#
# [5 rows x 48 columns]

# %% [markdown]
# ### OLS-30,40,40 with standardised data

# %%
data_level = initialise(pd.read_csv('/content/drive/MyDrive/Msc Thesis/code/data/Low resolution/data_level_standardized_selection10.csv'))
data_slope = initialise(pd.read_csv('/content/drive/MyDrive/Msc Thesis/code/data/Low resolution/data_slope_standardized_selection10.csv'))
data_curve = initialise(pd.read_csv('/content/drive/MyDrive/Msc Thesis/code/data/Low resolution/data_curve_standardized_selection10.csv'))

# # Loop sizes
# trainsize = 8 * 3000 * 12
# validatesize = 5 * 3000 * 12
# oossize = 3000 * 12

# Loop sizes
trainsize =  11
validatesize = 5
oossize = 1

# Initialise predictionstring
oos_pred_level = pd.DataFrame()
oos_pred_slope = pd.DataFrame()
oos_pred_curve = pd.DataFrame()

for window in range(2012, 2021+1):
  print('Iteration: ', window)
  best = float("inf")

  # Sample splitting LEVEL
  IV = 'level'
  train, validate, oos, total_train, total_oos = samplesplitting(data_level, trainsize, validatesize, oossize, window)
  train_x, train_y              = split_xy(train,IV)
  validate_x, validate_y        = split_xy(validate,IV)
  oos_x, oos_y                  = split_xy(oos,IV)
  total_train_x, total_train_y  = split_xy(total_train,IV)
  print(len(train), len(validate), len(oos), len(total_train), len(total_oos))
  total_oos_x, total_oos_y      = split_xy(total_oos, IV)

  # Fit model and produce forecasts
  model_final = LinearRegression()
  model_final.fit(total_train_x, total_train_y)
  print(model_final.coef_, total_train_x.columns.values.tolist())

  # Compute predictions
  y_hat = pd.DataFrame(model_final.predict(oos_x))
  print('Yearly level:',r2_score(oos_y, y_hat))
  oos_pred_level = pd.concat([oos_pred_level, y_hat], ignore_index=True)
  # print('Total level:',r2_score(total_oos[IV], oos_pred_level))
  print('Total level:',r2_score(total_oos_y, oos_pred_level))

  # Sample splitting SLOPE
  IV = 'slope'
  train, validate, oos, total_train, total_oos = samplesplitting(data_slope, trainsize, validatesize, oossize, window)
  train_x, train_y              = split_xy(train,IV)
  validate_x, validate_y        = split_xy(validate,IV)
  oos_x, oos_y                  = split_xy(oos,IV)
  total_train_x, total_train_y  = split_xy(total_train,IV)

  # Fit model and produce forecasts
  model_final = LinearRegression()
  model_final.fit(total_train_x, total_train_y)

  # Compute predictions
  y_hat = pd.DataFrame(model_final.predict(oos_x))
  print('Yearly slope:',r2_score(oos_y, y_hat))
  oos_pred_slope = pd.concat([oos_pred_slope, y_hat], ignore_index=True)
  print('Total slope:',r2_score(total_oos[IV], oos_pred_slope))

  # Sample splitting CURVE
  IV = 'curve'
  train, validate, oos, total_train, total_oos = samplesplitting(data_curve, trainsize, validatesize, oossize, window)
  train_x, train_y              = split_xy(train,IV)
  validate_x, validate_y        = split_xy(validate,IV)
  oos_x, oos_y                  = split_xy(oos,IV)
  total_train_x, total_train_y  = split_xy(total_train,IV)

  # Fit model and produce forecasts
  model_final = LinearRegression()
  model_final.fit(total_train_x, total_train_y)

  # Compute predictions
  y_hat = pd.DataFrame(model_final.predict(oos_x))
  print('Yearly curve:',r2_score(oos_y, y_hat))
  oos_pred_curve = pd.concat([oos_pred_curve, y_hat], ignore_index=True)
  print('Total curve:',r2_score(total_oos[IV], oos_pred_curve))

oos_pred_level.to_csv('/content/drive/MyDrive/Msc Thesis/code/Results/OLS/level_predictions_OLS30_st_yearly.csv', index=True)
oos_pred_slope.to_csv('/content/drive/MyDrive/Msc Thesis/code/Results/OLS/slope_predictions_OLS40_st_yearly.csv', index=True)
oos_pred_curve.to_csv('/content/drive/MyDrive/Msc Thesis/code/Results/OLS/curve_predictions_OLS40_st_yearly.csv', index=True)
# Out:
# Iteration:  2012
# train=210839, validate=158189, oos=33864
# 210839 158189 33864 369028 33864
# [ 1.72221397e-02 -8.39126290e-03 -2.18201244e-02  4.23629537e-02
#   2.13351287e-02  2.07933271e-03 -2.58110230e-03  1.88857955e-03
#   3.29047154e-03  6.09392313e-04 -1.46014428e-03  6.68661605e-03
#   2.66078168e-04 -2.65144611e-03  1.94853984e-03  2.10145352e-03
#  -4.98442869e-03 -1.02027946e-03  5.69682863e-03 -3.17645513e-03
#   1.11182223e-02 -6.54281447e-05 -9.30956089e-03  2.38632030e-03
#  -1.05818395e-03  9.16981920e-02 -6.82859575e-03  1.67379619e-02
#   2.25886281e-03 -1.22206889e-02] ['beta', 'betasq', 'dolvol', 'idiovol', 'turn', 'absacc', 'age', 'bm_ia', 'convind', 'dy', 'ep', 'mve_ia', 'orgcap', 'ps', 'rd', 'rd_mve', 'roic', 'secured', 'securedind', 'tang', 'cash', 'cinvest', 'roaq', 'roavol', 'ms', 'baspread', 'maxret', 'retvol', 'std_dolvol', 'std_turn']
# Yearly level: 0.36166070709188547
# Total level: 0.36166070709188547
# train=210839, validate=158189, oos=33864
# Yearly slope: -0.017834071477559554
# Total slope: -0.017834071477559554
# train=210839, validate=158189, oos=33864
# Yearly curve: -0.036848497383644485
# Total curve: -0.036848497383644485
# Iteration:  2013
# train=241135, validate=161757, oos=34182
# 241135 161757 34182 402892 68046
# [ 0.01557465 -0.00728096 -0.02438783  0.04143166  0.02144513  0.00193215
#  -0.00242726  0.00163858  0.00342945  0.00140477 -0.00193034  0.00715071
#   0.00043543 -0.00254358  0.00211804  0.00232622 -0.00508817 -0.00104644
#   0.00633444 -0.00388627  0.01233241  0.00026591 -0.00892176  0.00282497
#  -0.00070244  0.0916769  -0.00689296  0.01542102  0.00186282 -0.01187965] ['beta', 'betasq', 'dolvol', 'idiovol', 'turn', 'absacc', 'age', 'bm_ia', 'convind', 'dy', 'ep', 'mve_ia', 'orgcap', 'ps', 'rd', 'rd_mve', 'roic', 'secured', 'securedind', 'tang', 'cash', 'cinvest', 'roaq', 'roavol', 'ms', 'baspread', 'maxret', 'retvol', 'std_dolvol', 'std_turn']
# Yearly level: 0.21420592564538044
# Total level: 0.29589972981856383
# train=241135, validate=161757, oos=34182
# Yearly slope: 0.01403827935037627
# Total slope: 0.0016965594200912815
# train=241135, validate=161757, oos=34182
# Yearly curve: 0.0006051672099062211
# Total curve: -0.016315295240931338
# Iteration:  2014
# train=272284, validate=164790, oos=34113
# 272284 164790 34113 437074 102159
# [ 0.0135819  -0.00617649 -0.02613087  0.0415529   0.0218156   0.00181228
#  -0.00201394  0.00112598  0.00353886  0.00168576 -0.00198233  0.00773711
#   0.00045865 -0.00254724  0.00216428  0.00255951 -0.00554561 -0.00110298
#   0.00648738 -0.00415525  0.01259184  0.00026096 -0.00864515  0.00312716
#  -0.00063357  0.09106599 -0.00679849  0.01416956  0.00193814 -0.01187788] ['beta', 'betasq', 'dolvol', 'idiovol', 'turn', 'absacc', 'age', 'bm_ia', 'convind', 'dy', 'ep', 'mve_ia', 'orgcap', 'ps', 'rd', 'rd_mve', 'roic', 'secured', 'securedind', 'tang', 'cash', 'cinvest', 'roaq', 'roavol', 'ms', 'baspread', 'maxret', 'retvol', 'std_dolvol', 'std_turn']
# Yearly level: 0.29488931281453756
# Total level: 0.2965425593649067
# train=272284, validate=164790, oos=34113
# Yearly slope: -0.037243962349490456
# Total slope: -0.006688986974139777
# train=272284, validate=164790, oos=34113
# Yearly curve: -0.06936120094435538
# Total curve: -0.029591292519678625
# Iteration:  2015
# train=303150, validate=168037, oos=33074
# 303150 168037 33074 471187 135233
# [ 0.01157595 -0.00433581 -0.02808947  0.04133156  0.02199264  0.00200183
#  -0.00172412  0.00092479  0.00377774  0.00253086 -0.00200568  0.00827715
#   0.00056235 -0.00232292  0.00240201  0.00260569 -0.0056862  -0.00086991
#   0.00612076 -0.0046099   0.01264659  0.00035357 -0.00870511  0.00337071
#  -0.00062683  0.09088231 -0.00656617  0.01306476  0.00179835 -0.01171354] ['beta', 'betasq', 'dolvol', 'idiovol', 'turn', 'absacc', 'age', 'bm_ia', 'convind', 'dy', 'ep', 'mve_ia', 'orgcap', 'ps', 'rd', 'rd_mve', 'roic', 'secured', 'securedind', 'tang', 'cash', 'cinvest', 'roaq', 'roavol', 'ms', 'baspread', 'maxret', 'retvol', 'std_dolvol', 'std_turn']
# Yearly level: 0.4083556643586076
# Total level: 0.32614390157049067
# train=303150, validate=168037, oos=33074
# Yearly slope: -0.0463257668133239
# Total slope: -0.013961620493642135
# train=303150, validate=168037, oos=33074
# Yearly curve: -0.0644628516264274
# Total curve: -0.03600006434870662
# Iteration:  2016
# train=335237, validate=169024, oos=31906
# 335237 169024 31906 504261 167139
# [ 0.00961565 -0.0022988  -0.02974281  0.04138453  0.0225722   0.00222131
#  -0.00124698  0.00047585  0.00428154  0.00345655 -0.00194624  0.00880531
#   0.00051514 -0.00230792  0.00249303  0.00280122 -0.00537132 -0.00058195
#   0.00554736 -0.004686    0.01252806  0.00030381 -0.00852034  0.00368525
#  -0.00075911  0.09040192 -0.00695023  0.0133534   0.00202411 -0.01196648] ['beta', 'betasq', 'dolvol', 'idiovol', 'turn', 'absacc', 'age', 'bm_ia', 'convind', 'dy', 'ep', 'mve_ia', 'orgcap', 'ps', 'rd', 'rd_mve', 'roic', 'secured', 'securedind', 'tang', 'cash', 'cinvest', 'roaq', 'roavol', 'ms', 'baspread', 'maxret', 'retvol', 'std_dolvol', 'std_turn']
# Yearly level: 0.47511542914942717
# Total level: 0.3595114514132838
# train=335237, validate=169024, oos=31906
# Yearly slope: -0.031524240763519895
# Total slope: -0.016335110800780095
# train=335237, validate=169024, oos=31906
# Yearly curve: -0.1391378432530912
# Total curve: -0.04930619970515604
# Iteration:  2017
# train=369028, validate=167139, oos=30972
# 369028 167139 30972 536167 198111
# [ 8.32293838e-03 -7.76437063e-04 -3.08151863e-02  4.22754970e-02
#   2.30747151e-02  2.13616320e-03 -6.30681735e-04  6.59882566e-04
#   4.94342961e-03  4.07462725e-03 -1.91184186e-03  9.05961751e-03
#   6.01682930e-04 -2.20033331e-03  2.73746751e-03  2.97798456e-03
#  -5.85753806e-03 -2.02471835e-05  4.20183174e-03 -5.12199576e-03
#   1.25109543e-02  1.56576179e-04 -8.46815414e-03  4.17529424e-03
#  -6.66298665e-04  8.99107884e-02 -6.92408884e-03  1.31848119e-02
#   1.98952969e-03 -1.19006567e-02] ['beta', 'betasq', 'dolvol', 'idiovol', 'turn', 'absacc', 'age', 'bm_ia', 'convind', 'dy', 'ep', 'mve_ia', 'orgcap', 'ps', 'rd', 'rd_mve', 'roic', 'secured', 'securedind', 'tang', 'cash', 'cinvest', 'roaq', 'roavol', 'ms', 'baspread', 'maxret', 'retvol', 'std_dolvol', 'std_turn']
# Yearly level: 0.2595772721629239
# Total level: 0.3499331927810784
# train=369028, validate=167139, oos=30972
# Yearly slope: 0.018634896680278068
# Total slope: -0.010974175711027101
# train=369028, validate=167139, oos=30972
# Yearly curve: -0.03372459693602048
# Total curve: -0.0471110901765186
# Iteration:  2018
# train=402892, validate=164247, oos=30002
# 402892 164247 30002 567139 228113
# [ 7.95084944e-03 -6.78987435e-04 -3.06042637e-02  4.25766010e-02
#   2.32287021e-02  1.80669601e-03 -3.66878070e-04  8.27898358e-04
#   5.20440873e-03  4.47621854e-03 -1.76579942e-03  8.97362238e-03
#   9.54382108e-04 -2.23027041e-03  2.93025014e-03  3.02893804e-03
#  -5.83641000e-03  2.62002946e-04  3.41184720e-03 -5.86586048e-03
#   1.31295179e-02  1.41929465e-05 -8.61943587e-03  4.37536631e-03
#  -4.79899556e-04  8.93023446e-02 -6.51374238e-03  1.24321883e-02
#   2.00060894e-03 -1.16531416e-02] ['beta', 'betasq', 'dolvol', 'idiovol', 'turn', 'absacc', 'age', 'bm_ia', 'convind', 'dy', 'ep', 'mve_ia', 'orgcap', 'ps', 'rd', 'rd_mve', 'roic', 'secured', 'securedind', 'tang', 'cash', 'cinvest', 'roaq', 'roavol', 'ms', 'baspread', 'maxret', 'retvol', 'std_dolvol', 'std_turn']
# Yearly level: 0.40423791344175386
# Total level: 0.3572137897083726
# train=402892, validate=164247, oos=30002
# Yearly slope: 0.0023405951883038734
# Total slope: -0.008886202301932933
# train=402892, validate=164247, oos=30002
# Yearly curve: -0.029965901690885755
# Total curve: -0.044131563219638625
# Iteration:  2019
# train=437074, validate=160067, oos=28538
# 437074 160067 28538 597141 256651
# [ 7.48276439e-03 -4.76665572e-04 -3.12031242e-02  4.33223385e-02
#   2.37968344e-02  1.89975929e-03  4.79664503e-05  9.60061980e-04
#   5.29172397e-03  4.91820662e-03 -2.05270925e-03  9.19364317e-03
#   8.87793393e-04 -2.12983476e-03  3.08479263e-03  3.22233661e-03
#  -5.62271941e-03  2.54309180e-04  2.57507619e-03 -6.39326431e-03
#   1.35524140e-02 -9.03352644e-05 -8.79211790e-03  4.50726160e-03
#  -4.83216907e-04  8.85718251e-02 -6.67344924e-03  1.21824549e-02
#   2.21904244e-03 -1.17817253e-02] ['beta', 'betasq', 'dolvol', 'idiovol', 'turn', 'absacc', 'age', 'bm_ia', 'convind', 'dy', 'ep', 'mve_ia', 'orgcap', 'ps', 'rd', 'rd_mve', 'roic', 'secured', 'securedind', 'tang', 'cash', 'cinvest', 'roaq', 'roavol', 'ms', 'baspread', 'maxret', 'retvol', 'std_dolvol', 'std_turn']
# Yearly level: 0.4670391343726098
# Total level: 0.3697113713480722
# train=437074, validate=160067, oos=28538
# Yearly slope: -0.003827345805272442
# Total slope: -0.008050164025890538
# train=437074, validate=160067, oos=28538
# Yearly curve: -0.031404982784252855
# Total curve: -0.042209426976700826
# Iteration:  2020
# train=471187, validate=154492, oos=27289
# 471187 154492 27289 625679 283940
# [ 0.00628727  0.00022765 -0.03177737  0.04477783  0.02429829  0.00203583
#   0.00047556  0.00098083  0.00538769  0.00538638 -0.00217838  0.0094599
#   0.00102811 -0.00208366  0.00320423  0.00348121 -0.00496972  0.00020249
#   0.00193953 -0.00690309  0.01371679 -0.00013704 -0.00895082  0.00429938
#  -0.00051147  0.08810432 -0.0065126   0.01184326  0.00259091 -0.01189246] ['beta', 'betasq', 'dolvol', 'idiovol', 'turn', 'absacc', 'age', 'bm_ia', 'convind', 'dy', 'ep', 'mve_ia', 'orgcap', 'ps', 'rd', 'rd_mve', 'roic', 'secured', 'securedind', 'tang', 'cash', 'cinvest', 'roaq', 'roavol', 'ms', 'baspread', 'maxret', 'retvol', 'std_dolvol', 'std_turn']
# Yearly level: 0.22402231524372473
# Total level: 0.3791683319721897
# train=471187, validate=154492, oos=27289
# Yearly slope: -0.08501585191358796
# Total slope: -0.01218756379414776
# train=471187, validate=154492, oos=27289
# Yearly curve: -0.06392105769380008
# Total curve: -0.04199318513501704
# Iteration:  2021
# train=504261, validate=148707, oos=27899
# 504261 148707 27899 652968 311839
# [ 0.00469426  0.00159522 -0.03377152  0.04594656  0.02540885  0.00239167
#   0.0011282   0.00081493  0.00580312  0.00636302 -0.00222156  0.01018944
#   0.00125943 -0.00185655  0.00328269  0.00364806 -0.0047483   0.00067867
#   0.00090715 -0.00702229  0.01315833 -0.00038977 -0.00918283  0.00430914
#  -0.00056466  0.08918934 -0.00649426  0.01146213  0.00299607 -0.01177558] ['beta', 'betasq', 'dolvol', 'idiovol', 'turn', 'absacc', 'age', 'bm_ia', 'convind', 'dy', 'ep', 'mve_ia', 'orgcap', 'ps', 'rd', 'rd_mve', 'roic', 'secured', 'securedind', 'tang', 'cash', 'cinvest', 'roaq', 'roavol', 'ms', 'baspread', 'maxret', 'retvol', 'std_dolvol', 'std_turn']
# Yearly level: 0.5143523375166527
# Total level: 0.39728361175049076
# train=504261, validate=148707, oos=27899
# Yearly slope: -0.08421225612754224
# Total slope: -0.014527430523107787
# train=504261, validate=148707, oos=27899
# Yearly curve: -0.07104301799265023
# Total curve: -0.04240827920743051

# %% [markdown]
# ### OLS-30,40,40 with mapped data

# %%
# # Loop sizes
# trainsize = 8 * 3000 * 12
# validatesize = 5 * 3000 * 12
# oossize = 3000 * 12

data_level = initialise(pd.read_csv('/content/drive/MyDrive/Msc Thesis/code/data/Low resolution/data_level_mapped_selection10.csv'))
data_slope = initialise(pd.read_csv('/content/drive/MyDrive/Msc Thesis/code/data/Low resolution/data_slope_mapped_selection10.csv'))
data_curve = initialise(pd.read_csv('/content/drive/MyDrive/Msc Thesis/code/data/Low resolution/data_curve_mapped_selection10.csv'))

# Loop sizes
trainsize = 11
validatesize = 5
oossize = 1

# Initialise predictionstring
oos_pred_level = pd.DataFrame()
oos_pred_slope = pd.DataFrame()
oos_pred_curve = pd.DataFrame()

for window in range(2012, 2021+1):
  print('Iteration: ', window)
  best = float("inf")

  # Sample splitting LEVEL
  IV = 'level'
  train, validate, oos, total_train, total_oos = samplesplitting(data_level, trainsize, validatesize, oossize, window)
  train_x, train_y              = split_xy(train,IV)
  validate_x, validate_y        = split_xy(validate,IV)
  oos_x, oos_y                  = split_xy(oos,IV)
  total_train_x, total_train_y  = split_xy(total_train,IV)
  print(len(train), len(validate), len(oos), len(total_train), len(total_oos))
  total_oos_x, total_oos_y      = split_xy(total_oos, IV)

  # Fit model and produce forecasts
  model_final = LinearRegression()
  model_final.fit(total_train_x, total_train_y)
  print(model_final.coef_, total_train_x.columns.values.tolist())

  # Compute predictions
  y_hat = pd.DataFrame(model_final.predict(oos_x))
  print('Yearly level:',r2_score(oos_y, y_hat))
  oos_pred_level = pd.concat([oos_pred_level, y_hat], ignore_index=True)
  # print('Total level:',r2_score(total_oos[IV], oos_pred_level))
  print('Total level:',r2_score(total_oos_y, oos_pred_level))

  # Sample splitting SLOPE
  IV = 'slope'
  train, validate, oos, total_train, total_oos = samplesplitting(data_slope, trainsize, validatesize, oossize, window)
  train_x, train_y              = split_xy(train,IV)
  validate_x, validate_y        = split_xy(validate,IV)
  oos_x, oos_y                  = split_xy(oos,IV)
  total_train_x, total_train_y  = split_xy(total_train,IV)

  # Fit model and produce forecasts
  model_final = LinearRegression()
  model_final.fit(total_train_x, total_train_y)

  # Compute predictions
  y_hat = pd.DataFrame(model_final.predict(oos_x))
  print('Yearly slope:',r2_score(oos_y, y_hat))
  oos_pred_slope = pd.concat([oos_pred_slope, y_hat], ignore_index=True)
  print('Total slope:',r2_score(total_oos[IV], oos_pred_slope))

  # Sample splitting CURVE
  IV = 'curve'
  train, validate, oos, total_train, total_oos = samplesplitting(data_curve, trainsize, validatesize, oossize, window)
  train_x, train_y              = split_xy(train,IV)
  validate_x, validate_y        = split_xy(validate,IV)
  oos_x, oos_y                  = split_xy(oos,IV)
  total_train_x, total_train_y  = split_xy(total_train,IV)

  # Fit model and produce forecasts
  model_final = LinearRegression()
  model_final.fit(total_train_x, total_train_y)

  # Compute predictions
  y_hat = pd.DataFrame(model_final.predict(oos_x))
  print('Yearly curve:',r2_score(oos_y, y_hat))
  oos_pred_curve = pd.concat([oos_pred_curve, y_hat], ignore_index=True)
  print('Total curve:',r2_score(total_oos[IV], oos_pred_curve))

oos_pred_level.to_csv('/content/drive/MyDrive/Msc Thesis/code/Results/OLS/level_predictions_OLS30_mp_yearly.csv', index=True)
oos_pred_slope.to_csv('/content/drive/MyDrive/Msc Thesis/code/Results/OLS/slope_predictions_OLS40_mp_yearly.csv', index=True)
oos_pred_curve.to_csv('/content/drive/MyDrive/Msc Thesis/code/Results/OLS/curve_predictions_OLS40_mp_yearly.csv', index=True)
# Out:
# Iteration:  2012
# train=210839, validate=158189, oos=33864
# 210839 158189 33864 369028 33864
# [-0.0343023   0.05150057 -0.02704873  0.20431636  0.03102563  0.00758864
#  -0.00126121  0.09158587  0.00108161 -0.03914628  0.06019839 -0.01584863
#   0.01777089 -0.06031628  0.00503959 -0.01102379 -0.00131488 -0.00407655
#   0.00855185 -0.01170454  0.02243872  0.02754758 -0.00219903  0.01934132
#  -0.01029732  0.36096483 -0.00254311  0.01989946  0.01321047  0.00137822] ['beta', 'betasq', 'dolvol', 'idiovol', 'turn', 'absacc', 'age', 'bm_ia', 'convind', 'dy', 'ep', 'mve_ia', 'orgcap', 'ps', 'rd', 'rd_mve', 'roic', 'secured', 'securedind', 'tang', 'cash', 'cinvest', 'roaq', 'roavol', 'ms', 'baspread', 'maxret', 'retvol', 'std_dolvol', 'std_turn']
# Yearly level: 0.41500698171047345
# Total level: 0.41500698171047345
# train=210839, validate=158189, oos=33864
# Yearly slope: 0.005886130116876109
# Total slope: 0.005886130116876109
# train=210839, validate=158189, oos=33864
# Yearly curve: -0.005606506170369396
# Total curve: -0.005606506170369396
# Iteration:  2013
# train=241135, validate=161757, oos=34182
# 241135 161757 34182 402892 68046
# [-0.03242054  0.04808897 -0.03624861  0.19891907  0.03427524  0.006054
#  -0.0009439   0.08665978  0.0013892  -0.0388393   0.05516242 -0.01243645
#   0.0168688  -0.05728899  0.00517358 -0.00734524 -0.00454502 -0.00398212
#   0.00890328 -0.01264766  0.02426181  0.02820251 -0.00443794  0.02140108
#  -0.00866048  0.36407103 -0.00628542  0.01839192  0.01454052 -0.00168957] ['beta', 'betasq', 'dolvol', 'idiovol', 'turn', 'absacc', 'age', 'bm_ia', 'convind', 'dy', 'ep', 'mve_ia', 'orgcap', 'ps', 'rd', 'rd_mve', 'roic', 'secured', 'securedind', 'tang', 'cash', 'cinvest', 'roaq', 'roavol', 'ms', 'baspread', 'maxret', 'retvol', 'std_dolvol', 'std_turn']
# Yearly level: 0.3480913322848116
# Total level: 0.38840583701129827
# train=241135, validate=161757, oos=34182
# Yearly slope: 0.01596748769780454
# Total slope: 0.014847787563311732
# train=241135, validate=161757, oos=34182
# Yearly curve: 0.0027740207816878693
# Total curve: 0.0009747460627930193
# Iteration:  2014
# train=272284, validate=164790, oos=34113
# 272284 164790 34113 437074 102159
# [-0.04370425  0.05130673 -0.04090157  0.20015081  0.04185109  0.00636395
#  -0.00046273  0.08597598  0.00171702 -0.04176114  0.06576768 -0.00987505
#   0.01696381 -0.05641229  0.00542645 -0.00210278 -0.01327442 -0.00970563
#   0.00901539 -0.0110336   0.02205585  0.02082629 -0.00394586  0.02275622
#  -0.00824366  0.37379769 -0.00725363  0.01122846  0.02018702 -0.00563854] ['beta', 'betasq', 'dolvol', 'idiovol', 'turn', 'absacc', 'age', 'bm_ia', 'convind', 'dy', 'ep', 'mve_ia', 'orgcap', 'ps', 'rd', 'rd_mve', 'roic', 'secured', 'securedind', 'tang', 'cash', 'cinvest', 'roaq', 'roavol', 'ms', 'baspread', 'maxret', 'retvol', 'std_dolvol', 'std_turn']
# Yearly level: 0.36852457687556883
# Total level: 0.38235032000244606
# train=272284, validate=164790, oos=34113
# Yearly slope: -0.004305870629888187
# Total slope: 0.015096910004055553
# train=272284, validate=164790, oos=34113
# Yearly curve: -0.049761333367268845
# Total curve: -0.011507787474102305
# Iteration:  2015
# train=303150, validate=168037, oos=33074
# 303150 168037 33074 471187 135233
# [-5.42323473e-02  5.76442446e-02 -4.71743898e-02  2.03288131e-01
#   4.74339119e-02  7.29669455e-03 -1.88873585e-04  8.67671906e-02
#   2.59889865e-03 -3.81421078e-02  7.40164604e-02 -6.59999218e-03
#   1.81040564e-02 -5.53744497e-02  5.87130043e-03 -1.25192308e-03
#  -1.94991756e-02 -1.31221399e-02  8.26451499e-03 -1.05884361e-02
#   1.97165271e-02  1.46521494e-02 -6.53834660e-03  2.51809065e-02
#  -7.19839130e-03  3.83231695e-01 -7.30848924e-03 -5.01865097e-04
#   2.57904088e-02 -8.06621633e-03] ['beta', 'betasq', 'dolvol', 'idiovol', 'turn', 'absacc', 'age', 'bm_ia', 'convind', 'dy', 'ep', 'mve_ia', 'orgcap', 'ps', 'rd', 'rd_mve', 'roic', 'secured', 'securedind', 'tang', 'cash', 'cinvest', 'roaq', 'roavol', 'ms', 'baspread', 'maxret', 'retvol', 'std_dolvol', 'std_turn']
# Yearly level: 0.43968313754264376
# Total level: 0.39770759703121406
# train=303150, validate=168037, oos=33074
# Yearly slope: -0.003939516895088868
# Total slope: 0.01387735186361716
# train=303150, validate=168037, oos=33074
# Yearly curve: -0.021706768466923876
# Total curve: -0.010521897546510672
# Iteration:  2016
# train=335237, validate=169024, oos=31906
# 335237 169024 31906 504261 167139
# [-5.74792373e-02  6.11936545e-02 -5.40537991e-02  2.02166607e-01
#   5.21876856e-02  7.89076854e-03  4.71485547e-04  7.85106105e-02
#   3.50482151e-03 -3.58903123e-02  7.08450258e-02 -2.28229588e-03
#   1.65163825e-02 -5.34993412e-02  5.79469763e-03  1.52007707e-03
#  -2.26330726e-02 -1.23785531e-02  7.34921964e-03 -9.39473213e-03
#   1.79458161e-02  2.03981743e-02 -5.65921900e-03  2.72353401e-02
#  -7.38015743e-03  3.84855443e-01 -8.85021998e-03 -1.52589121e-04
#   2.96385031e-02 -1.21264309e-02] ['beta', 'betasq', 'dolvol', 'idiovol', 'turn', 'absacc', 'age', 'bm_ia', 'convind', 'dy', 'ep', 'mve_ia', 'orgcap', 'ps', 'rd', 'rd_mve', 'roic', 'secured', 'securedind', 'tang', 'cash', 'cinvest', 'roaq', 'roavol', 'ms', 'baspread', 'maxret', 'retvol', 'std_dolvol', 'std_turn']
# Yearly level: 0.45108253502872064
# Total level: 0.410317304663919
# train=335237, validate=169024, oos=31906
# Yearly slope: 0.02091613854665164
# Total slope: 0.016201423406895565
# train=335237, validate=169024, oos=31906
# Yearly curve: -0.05335186913371537
# Total curve: -0.010117361467190777
# Iteration:  2017
# train=369028, validate=167139, oos=30972
# 369028 167139 30972 536167 198111
# [-0.05582587  0.05953979 -0.05881768  0.20388268  0.0535549   0.0081754
#   0.00140249  0.07408377  0.00452345 -0.03579979  0.06114388  0.00067402
#   0.01566577 -0.05294068  0.00605489  0.00239167 -0.02244407 -0.00857364
#   0.00609942 -0.01042805  0.01862539  0.01934763 -0.00373658  0.02861454
#  -0.00782322  0.38419824 -0.00976825 -0.00044756  0.02578413 -0.0106066 ] ['beta', 'betasq', 'dolvol', 'idiovol', 'turn', 'absacc', 'age', 'bm_ia', 'convind', 'dy', 'ep', 'mve_ia', 'orgcap', 'ps', 'rd', 'rd_mve', 'roic', 'secured', 'securedind', 'tang', 'cash', 'cinvest', 'roaq', 'roavol', 'ms', 'baspread', 'maxret', 'retvol', 'std_dolvol', 'std_turn']
# Yearly level: 0.4379802602940084
# Total level: 0.4169687456803729
# train=369028, validate=167139, oos=30972
# Yearly slope: 0.013267933856972669
# Total slope: 0.016588099780429966
# train=369028, validate=167139, oos=30972
# Yearly curve: 0.008573843141137405
# Total curve: -0.007484346825652022
# Iteration:  2018
# train=402892, validate=164247, oos=30002
# 402892 164247 30002 567139 228113
# [-0.0543366   0.05944539 -0.05979631  0.20580912  0.05619688  0.00601985
#   0.00144374  0.07531558  0.00527083 -0.0333474   0.05399209  0.0019268
#   0.01781272 -0.05031881  0.00569929  0.00159539 -0.02835709 -0.01035312
#   0.00452161 -0.01143349  0.01825563  0.01587001 -0.00741298  0.03060354
#  -0.00632361  0.38655442 -0.00960201 -0.00385068  0.02900166 -0.01150129] ['beta', 'betasq', 'dolvol', 'idiovol', 'turn', 'absacc', 'age', 'bm_ia', 'convind', 'dy', 'ep', 'mve_ia', 'orgcap', 'ps', 'rd', 'rd_mve', 'roic', 'secured', 'securedind', 'tang', 'cash', 'cinvest', 'roaq', 'roavol', 'ms', 'baspread', 'maxret', 'retvol', 'std_dolvol', 'std_turn']
# Yearly level: 0.4333684180450338
# Total level: 0.4191709180352251
# train=402892, validate=164247, oos=30002
# Yearly slope: 0.0029291758500562537
# Total slope: 0.014641738181334518
# train=402892, validate=164247, oos=30002
# Yearly curve: -0.0021740356452064624
# Total curve: -0.006303258416719526
# Iteration:  2019
# train=437074, validate=160067, oos=28538
# 437074 160067 28538 597141 256651
# [-0.05080193  0.05601537 -0.06149861  0.20955634  0.05823952  0.00687803
#   0.00219392  0.07356186  0.00574564 -0.03175849  0.04898919  0.00310595
#   0.01796505 -0.04952622  0.00590366  0.00355931 -0.02778466 -0.00938846
#   0.00343865 -0.0126573   0.01923942  0.01737987 -0.0078962   0.03017459
#  -0.00674488  0.3868486  -0.0109384  -0.00535108  0.03146143 -0.01307518] ['beta', 'betasq', 'dolvol', 'idiovol', 'turn', 'absacc', 'age', 'bm_ia', 'convind', 'dy', 'ep', 'mve_ia', 'orgcap', 'ps', 'rd', 'rd_mve', 'roic', 'secured', 'securedind', 'tang', 'cash', 'cinvest', 'roaq', 'roavol', 'ms', 'baspread', 'maxret', 'retvol', 'std_dolvol', 'std_turn']
# Yearly level: 0.5018578763798263
# Total level: 0.42858947143928516
# train=437074, validate=160067, oos=28538
# Yearly slope: 0.02377695976244021
# Total slope: 0.015925956741314695
# train=437074, validate=160067, oos=28538
# Yearly curve: 0.012988159754685147
# Total curve: -0.0036470801785506435
# Iteration:  2020
# train=471187, validate=154492, oos=27289
# 471187 154492 27289 625679 283940
# [-0.05154783  0.05633787 -0.06507893  0.21421963  0.06165107  0.00761269
#   0.00285084  0.07168057  0.00622133 -0.0303449   0.0449061   0.00538297
#   0.01902182 -0.04769041  0.00603548  0.00531661 -0.02623345 -0.0087628
#   0.00252963 -0.01414108  0.01985462  0.01904152 -0.00819365  0.02882423
#  -0.00716233  0.38546907 -0.01099331 -0.00347043  0.03319084 -0.01578031] ['beta', 'betasq', 'dolvol', 'idiovol', 'turn', 'absacc', 'age', 'bm_ia', 'convind', 'dy', 'ep', 'mve_ia', 'orgcap', 'ps', 'rd', 'rd_mve', 'roic', 'secured', 'securedind', 'tang', 'cash', 'cinvest', 'roaq', 'roavol', 'ms', 'baspread', 'maxret', 'retvol', 'std_dolvol', 'std_turn']
# Yearly level: 0.16444698820076598
# Total level: 0.41489734748103924
# train=471187, validate=154492, oos=27289
# Yearly slope: -0.018638889096991296
# Total slope: 0.01846402591913765
# train=471187, validate=154492, oos=27289
# Yearly curve: -0.011859879408841367
# Total curve: -0.0015334888391933532
# Iteration:  2021
# train=504261, validate=148707, oos=27899
# 504261 148707 27899 652968 311839
# [-0.04935898  0.05713264 -0.06928271  0.20366689  0.04953812  0.00933718
#   0.00477228  0.07262498  0.00666602 -0.0317141   0.04971916  0.00090599
#   0.01626125 -0.05254429  0.00682141  0.00240564 -0.02228997 -0.00416418
#   0.00237887 -0.01686321  0.02154705  0.0434719   0.00569233  0.03150784
#  -0.00847427  0.40186743 -0.02369982  0.01542327  0.02001863 -0.01361501] ['beta', 'betasq', 'dolvol', 'idiovol', 'turn', 'absacc', 'age', 'bm_ia', 'convind', 'dy', 'ep', 'mve_ia', 'orgcap', 'ps', 'rd', 'rd_mve', 'roic', 'secured', 'securedind', 'tang', 'cash', 'cinvest', 'roaq', 'roavol', 'ms', 'baspread', 'maxret', 'retvol', 'std_dolvol', 'std_turn']
# Yearly level: 0.49096664105105514
# Total level: 0.42601568699060655
# train=504261, validate=148707, oos=27899
# Yearly slope: -0.02394561730654332
# Total slope: 0.019755949249925076
# train=504261, validate=148707, oos=27899
# Yearly curve: -0.030437681233702163
# Total curve: -0.0020401692049720754

# %% [markdown]
# # OLS - 3/4

# %% [markdown]
# ### OLS - 4 regressors (market beta (beta), bid-ask spread (baspread), book to market ratio (bm of bm_ia), leverage(lev)) (industry adjusted)

# %%
data_mp = data.copy()

# %%
df = data_mp.copy()
selected_columns = df.iloc[:, :8]  # Selecting the first 8 columns
# additional_columns = df[['bm_ia', 'beta', 'baspread', 'lev']]  # Selecting additional specific columns
additional_columns = df[['bm_ia', 'beta', 'baspread', 'lev']]  # Selecting additional specific columns
# additional_columns = df[[ 'beta', 'baspread', 'lev']]  # Selecting additional specific columns
data = pd.concat([selected_columns, additional_columns], axis=1)
data.head()
# Out:
#              secid       -80       -50       -20     level     slope  \
# date
# 1996-01-31  100862  0.307688  0.315627  0.358095  0.315627  0.042468
# 1996-01-31  100871  0.705411  0.615432  0.651160  0.615432  0.035728
# 1996-01-31  100892  0.270090  0.216768  0.216508  0.216768 -0.000260
# 1996-01-31  100896  0.430796  0.436291  0.429517  0.436291 -0.006774
# 1996-01-31  100903  0.262405  0.252683  0.373839  0.252683  0.121156
#
#                curve  permno     bm_ia      beta  baspread       lev
# date
# 1996-01-31  0.017264   54594  0.328068 -0.502126 -0.689049 -0.918140
# 1996-01-31  0.062854   50906  0.302852  0.551365 -0.112575 -0.995785
# 1996-01-31  0.026531   57904  0.293655 -0.536730 -0.786859 -0.491185
# 1996-01-31 -0.006135   77520  0.286002  0.349363 -0.747736 -0.821394
# 1996-01-31  0.065439   80303  0.171681 -0.186662 -0.807682 -0.838204

# %%
# Complete number of observations is 680867
# We take the initial train, validate and oos sample to be 8, 5 and 13 years respectively (Ratios similar to Gu Kelly Xiu)
# On average one month contains 2000 options, therefore we loop over 12 * 2000 options, which is similar to looping over a year

# # Loop sizes
# trainsize = 8 * 3000 * 12
# validatesize = 5 * 3000 * 12
# oossize = 3000 * 12

# Loop sizes
trainsize = 11
validatesize = 5
oossize = 1

# Initialise predictionstring
IV = 'level'
oos_pred_level = pd.DataFrame()
oos_pred_slope = pd.DataFrame()
oos_pred_curve = pd.DataFrame()

for window in range(2012, 2021+1):
  print('Iteration: ', window)
  best = float("inf")

  # Sample splitting LEVEL
  IV = 'level'
  train, validate, oos, total_train, total_oos = samplesplitting(data, trainsize, validatesize, oossize, window)
  train_x, train_y              = split_xy(train,IV)
  validate_x, validate_y        = split_xy(validate,IV)
  oos_x, oos_y                  = split_xy(oos,IV)
  total_train_x, total_train_y  = split_xy(total_train,IV)

  # Fit model and produce forecasts
  model_final = LinearRegression()
  model_final.fit(total_train_x, total_train_y)

  # Compute predictions
  y_hat = pd.DataFrame(model_final.predict(oos_x))
  print('Yearly level:',r2_score(oos_y, y_hat))
  oos_pred_level = pd.concat([oos_pred_level, y_hat], ignore_index=True)
  print('Total level:',r2_score(total_oos[IV], oos_pred_level))

  # Sample splitting SLOPE
  IV = 'slope'
  train, validate, oos, total_train, total_oos = samplesplitting(data, trainsize, validatesize, oossize, window)
  train_x, train_y              = split_xy(train,IV)
  validate_x, validate_y        = split_xy(validate,IV)
  oos_x, oos_y                  = split_xy(oos,IV)
  total_train_x, total_train_y  = split_xy(total_train,IV)

  # Fit model and produce forecasts
  model_final = LinearRegression()
  model_final.fit(total_train_x, total_train_y)

  # Compute predictions
  y_hat = pd.DataFrame(model_final.predict(oos_x))
  print('Yearly slope:',r2_score(oos_y, y_hat))
  oos_pred_slope = pd.concat([oos_pred_slope, y_hat], ignore_index=True)
  print('Total slope:',r2_score(total_oos[IV], oos_pred_slope))

  # Sample splitting CURVE
  IV = 'curve'
  train, validate, oos, total_train, total_oos = samplesplitting(data, trainsize, validatesize, oossize, window)
  train_x, train_y              = split_xy(train,IV)
  validate_x, validate_y        = split_xy(validate,IV)
  oos_x, oos_y                  = split_xy(oos,IV)
  total_train_x, total_train_y  = split_xy(total_train,IV)

  # Fit model and produce forecasts
  model_final = LinearRegression()
  model_final.fit(total_train_x, total_train_y)

  # Compute predictions
  y_hat = pd.DataFrame(model_final.predict(oos_x))
  print('Yearly curve:',r2_score(oos_y, y_hat))
  oos_pred_curve = pd.concat([oos_pred_curve, y_hat], ignore_index=True)
  print('Total curve:',r2_score(total_oos[IV], oos_pred_curve))

print('Total level:',r2_score(total_oos['level'], oos_pred_level))
print('Total slope:',r2_score(total_oos['slope'], oos_pred_slope))
print('Total curve:',r2_score(total_oos['curve'], oos_pred_curve))

oos_pred_level.to_csv('/content/drive/MyDrive/Msc Thesis/code/Results/OLS/level_predictions_OLS4_mp_yearly.csv', index=True)
oos_pred_slope.to_csv('/content/drive/MyDrive/Msc Thesis/code/Results/OLS/slope_predictions_OLS4_mp_yearly.csv', index=True)
oos_pred_curve.to_csv('/content/drive/MyDrive/Msc Thesis/code/Results/OLS/curve_predictions_OLS4_mp_yearly.csv', index=True)
# Out:
# Iteration:  2012
# train=210839, validate=158189, oos=33864
# Yearly level: 0.3026905949529918
# Total level: 0.3026905949529918
# train=210839, validate=158189, oos=33864
# Yearly slope: -0.0277214684751812
# Total slope: -0.0277214684751812
# train=210839, validate=158189, oos=33864
# Yearly curve: -0.04609021704744687
# Total curve: -0.04609021704744687
# Iteration:  2013
# train=241135, validate=161757, oos=34182
# Yearly level: 0.19893465218711093
# Total level: 0.25914191328324043
# train=241135, validate=161757, oos=34182
# Yearly slope: 0.0029426408533388404
# Total slope: -0.008730453877434652
# train=241135, validate=161757, oos=34182
# Yearly curve: -0.008436194219447968
# Total curve: -0.025437682712105003
# Iteration:  2014
# train=272284, validate=164790, oos=34113
# Yearly level: 0.2932002220661072
# Total level: 0.2720417575307774
# train=272284, validate=164790, oos=34113
# Yearly slope: -0.053017655522702656
# Total slope: -0.01938836511283837
# train=272284, validate=164790, oos=34113
# Yearly curve: -0.08019361447294071
# Total curve: -0.03933047920296695
# Iteration:  2015
# train=303150, validate=168037, oos=33074
# Yearly level: 0.3671700590866914
# Total level: 0.29731617706578406
# train=303150, validate=168037, oos=33074
# Yearly slope: -0.07052365931460325
# Total slope: -0.030037203986722716
# train=303150, validate=168037, oos=33074
# Yearly curve: -0.08178560304399118
# Total curve: -0.047995300568472565
# Iteration:  2016
# train=335237, validate=169024, oos=31906
# Yearly level: 0.4089637592168669
# Total level: 0.322682163390525
# train=335237, validate=169024, oos=31906
# Yearly slope: -0.034564427615312976
# Total slope: -0.029891235257877735
# train=335237, validate=169024, oos=31906
# Yearly curve: -0.14369575049966699
# Total curve: -0.059455907987055134
# Iteration:  2017
# train=369028, validate=167139, oos=30972
# Yearly level: 0.398633020986651
# Total level: 0.3360329021703523
# train=369028, validate=167139, oos=30972
# Yearly slope: 0.0019329896198780894
# Total slope: -0.024930418011238187
# train=369028, validate=167139, oos=30972
# Yearly curve: -0.033475614380665375
# Total curve: -0.05579632137890922
# Iteration:  2018
# train=402892, validate=164247, oos=30002
# Yearly level: 0.365771850026559
# Total level: 0.3400227536062058
# train=402892, validate=164247, oos=30002
# Yearly slope: -0.01389505543663283
# Total slope: -0.023181789138360998
# train=402892, validate=164247, oos=30002
# Yearly curve: -0.04284162240886835
# Total curve: -0.05344499773915112
# Iteration:  2019
# train=437074, validate=160067, oos=28538
# Yearly level: 0.4214575182491169
# Total level: 0.3493070133307564
# train=437074, validate=160067, oos=28538
# Yearly slope: -0.020307004585425226
# Total slope: -0.0225854255104887
# train=437074, validate=160067, oos=28538
# Yearly curve: -0.04824439163212002
# Total curve: -0.05237958230103623
# Iteration:  2020
# train=471187, validate=154492, oos=27289
# Yearly level: 0.1818269671766337
# Total level: 0.35619136594382494
# train=471187, validate=154492, oos=27289
# Yearly slope: -0.11060508804499514
# Total slope: -0.028394590305394374
# train=471187, validate=154492, oos=27289
# Yearly curve: -0.08610676476458945
# Total curve: -0.053932738005588954
# Iteration:  2021
# train=504261, validate=148707, oos=27899
# Yearly level: 0.4283742879307312
# Total level: 0.3670891826408734
# train=504261, validate=148707, oos=27899
# Yearly slope: -0.10972361373662753
# Total slope: -0.03182993441139215
# train=504261, validate=148707, oos=27899
# Yearly curve: -0.09620264457659466
# Total curve: -0.05576554648196974
# Total level: 0.3670891826408734
# Total slope: -0.03182993441139215
# Total curve: -0.05576554648196974

# %% [markdown]
# 4 bm:
# Total level: 0.340108358738355
# Total slope: -0.023456188163347047
# Total curve: -0.05388141545634917

# %% [markdown]
# 4 (bm_ia): Total level: 0.34952603959697404
# Total slope: -0.021262673217462114
# Total curve: -0.05307616452170083

# %% [markdown]
# zonder lev: Total level: 0.33944472901101874
# Total slope: -0.023441170891076668
# Total curve: -0.05403927183921575

# %% [markdown]
# zonder bs: Total level: -0.010496210677015227
# Total slope: -0.028609936612457254
# Total curve: -0.05675022035882216

# %% [markdown]
# zonder beta:
# Total level: 0.340108358738355
# Total slope: -0.023456188163347047
# Total curve: -0.05388141545634917
